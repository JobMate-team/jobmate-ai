# %%
# ! pip install quantstats

# %%
# conda install -c conda-forge pyportfolioopt

# %%
import pandas as pd
import numpy as np
import quantstats as qs
import matplotlib.pyplot as plt 
import pymysql
from sqlalchemy import create_engine
from matplotlib import font_manager, rc

FONT_NAME = font_manager.FontProperties(fname="c:/Windows/Fonts/Gothic.ttf").get_name()
rc('font', family=FONT_NAME)

# %%
import warnings      # 경고 메시지 차단
warnings.filterwarnings('ignore')

# %%
# 성과분석을 위한 모듈 
from cal_nav_module import *               # 성과분석을 위한 기초 데이터 생성
from quant_model_modules_수정분 import *   # 성과평가를 위한 모듈

# %%
# MV/MVP/RP/MD 모형

folder_dir = 'D:/data/실습데이터'
DATA_FILE = "kospi_price_2025.csv"
adj_price = pd.read_csv(folder_dir + "/" + DATA_FILE, header=0,index_col=0,encoding='utf8')
adj_price.index=pd.to_datetime(adj_price.index)  # 일반 인덱스를 날짜형 DatetimeIndex로 변환
adj_price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3859 entries, 2010-01-04 to 2025-09-01
# Columns: 821 entries, AJ네트웍스 to 흥아해운
# dtypes: float64(214), int64(607)
# memory usage: 24.2 MB

# %%
df =adj_price[['LG전자','현대차','NAVER','삼성물산','SK텔레콤','KT&G']].loc['2010-01-01':'2025-09-01']

# %%
df = df[df.index> '2014-05-01']

# %%
ret=df.pct_change().fillna(0)
print(ret.tail(5))
# Out:
#                 LG전자       현대차     NAVER      삼성물산     SK텔레콤      KT&G
# Date
# 2025-08-26 -0.007905 -0.015766 -0.019956 -0.022809 -0.001812 -0.002901
# 2025-08-27 -0.001328  0.006865 -0.013575  0.003686  0.005445 -0.003636
# 2025-08-28  0.000000  0.009091 -0.002294  0.034884 -0.009025 -0.007299
# 2025-08-29 -0.017287 -0.009009 -0.013793 -0.007688 -0.012750 -0.009559
# 2025-09-01 -0.023004  0.002273  0.004662 -0.008343  0.011070  0.017817

# %%
# Setting

rebal_periods = 'A-DEC'  # https://pandas.pydata.org/docs/user_guide/timeseries.html#timeseries-offset-aliases ,'W-MON' Q-DEC
init = 100               # index 시작값
bp = 0.0000              # tc: Transaction cost

st_date = '2016-01-02'   # Backtest 시작일
ed_date = '2025-08-13'   # Backtest 종료일

lookback_periods = 252

# %% [markdown]
# ####  Mean Variance Max Sharpe= tangent  portfolio

# %%
MVMS_Pw = MeanVarianceMaxSharpe(rebal_periods, ret, lookback_periods)
MVMS_idx, _, _ = cal_nav(MVMS_Pw,
                    st_date,
                    ed_date,
                    init,
                    bp,
                    ret.loc[:, MVMS_Pw.columns])

MVMS_idx.name = 'Max_sharpe_1yr'

print(MVMS_Pw.head(5))
# Out:
#                     LG전자           현대차         NAVER          삼성물산  \
# Date
# 2015-12-30  8.852474e-18  0.000000e+00  1.571518e-16  3.831264e-03
# 2016-12-29  4.718448e-16  0.000000e+00  1.000000e+00  0.000000e+00
# 2017-12-28  5.678973e-01  8.028255e-02  1.670852e-16  3.472700e-16
# 2018-12-28  1.373999e-14  9.199236e-15  1.177337e-14  0.000000e+00
# 2019-12-30  1.984285e-01  0.000000e+00  8.015715e-01  4.149833e-18
#
#                    SK텔레콤          KT&G
# Date
# 2015-12-30  0.000000e+00  9.961687e-01
# 2016-12-29  1.942890e-16  0.000000e+00
# 2017-12-28  2.303586e-01  1.214616e-01
# 2018-12-28  1.000000e+00  5.835701e-15
# 2019-12-30  1.235990e-16  1.569847e-16

# %%
# 그래프 폰트 옵션 설정

plt.rc('font',family='Malgun Gothic')     # 한글 폰트 깨지지 않도록 폰트지정
plt.rcParams['axes.unicode_minus']=False  # 그래프 축 스케일 마이너스 숫자 깨짐 방지  
plt.figure(figsize=(10,3))

# %%
#  연도별 리밸런싱 시점별 투자비중 변화 추이
MVMS_Pw.plot.bar(stacked=True,legend='reverse', figsize=(10,4))
plt.legend(fontsize=7,loc='center')

# %% [markdown]
# ####  Mean Variance Minimum Volatility = MVP

# %%
MVMV_Pw = MeanVarianceMinVolatility(rebal_periods, ret, lookback_periods)
MVMV_idx, _, _ = cal_nav(MVMV_Pw,
                    st_date,
                    ed_date,
                    init,
                    bp,
                    ret.loc[:, MVMV_Pw.columns])
MVMV_idx.name = 'MVP_1 yr'

print(MVMV_Pw.head(3))
# Out:
#                 LG전자       현대차     NAVER      삼성물산     SK텔레콤      KT&G
# Date
# 2015-12-30  0.161494  0.213702  0.135137  0.029007  0.277732  0.182928
# 2016-12-29  0.125713  0.170029  0.119712  0.110091  0.263926  0.210530
# 2017-12-28  0.095099  0.139821  0.116621  0.185332  0.222547  0.240580

# %%
#  연도별 리밸런싱 시점별 투자비중 변화 추이

MVMV_Pw.plot.bar(stacked=True,legend='reverse', figsize=(10,4))
plt.legend(fontsize=7,loc='center')

# %% [markdown]
# #### Risk Parity

# %%
RP_Pw = RP(rebal_periods, ret, lookback_periods)
RP_idx, _, _ = cal_nav(RP_Pw,
                    st_date,
                    ed_date,
                    init,
                    bp,
                    ret.loc[:, RP_Pw.columns])

RP_idx.name = 'RP_1yr'

print(RP_Pw.head(3))
print(RP_idx.head(3))
# Out:
#                 LG전자       현대차     NAVER      삼성물산     SK텔레콤      KT&G
# Date
# 2015-12-30  0.164045  0.187181  0.158737  0.098729  0.210065  0.181243
# 2016-12-29  0.151292  0.170523  0.146248  0.140675  0.201406  0.189856
# 2017-12-28  0.128505  0.155000  0.143620  0.172345  0.197694  0.202835
# Date
# 2016-01-04         100.0
# 2016-01-05    100.617876
# 2016-01-06    100.386136
# Name: RP_1yr, dtype: object

# %%
#  연도별 리밸런싱 시점별 투자비중 변화 추이
RP_Pw.plot.bar(stacked=True,legend='reverse', figsize=(10,4))
plt.legend(fontsize=7,loc='center')

# %% [markdown]
# ####  Maximize Diversification

# %%
MD_Pw = MaximizeDiversification(rebal_periods, ret, lookback_periods)
print(MD_Pw.head(5))
# Out:
#                LG전자      현대차    NAVER     삼성물산    SK텔레콤     KT&G
# Date
# 2015-12-30  0.15785  0.19422  0.16431  0.09148  0.20284  0.18930
# 2016-12-29  0.14280  0.15141  0.14378  0.14404  0.19524  0.22274
# 2017-12-28  0.13470  0.15513  0.12381  0.16923  0.20218  0.21496
# 2018-12-28  0.13974  0.17472  0.13332  0.07624  0.22517  0.25080
# 2019-12-30  0.14759  0.08466  0.12716  0.11956  0.29125  0.22979

# %%
#  연도별 리밸런싱 시점별 투자비중 변화 추이
MD_Pw.plot.bar(stacked=True,legend='reverse', figsize=(10,4))
plt.legend(fontsize=7,loc='center')

# %%
MD_idx, _, _ = cal_nav(MD_Pw,
                        st_date,
                        ed_date,
                        init,
                        bp,
                        ret.loc[:, MD_Pw.columns])
MD_idx.name = 'MD_1yr'

# %% [markdown]
# ##### 자산배분 모형간 성과비교

# %%
ct = pd.concat([MVMS_idx, MVMV_idx,RP_idx, MD_idx], axis=1)

# %%
ax=ct.plot(figsize=(8,4))
ax.legend(fontsize=9)
plt.show()
